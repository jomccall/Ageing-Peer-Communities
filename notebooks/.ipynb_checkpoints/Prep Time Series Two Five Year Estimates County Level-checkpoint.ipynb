# %% [markdown]
# ###### Imports

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# # This file outlines the prep for the 2014 and 2019 5 year ACS estimate values to be used in a cluster analysis for finding peer communities in terms of our ageing population.

# %% [markdown]
# ### First we will create API calls for the population and home value data from the Census Bureau ACS 5 year estimates.

# %% [markdown]
# ###### The data we're curious about comes divided by sex or race - for now we're going to look at sex and then total them together because it's less data to deal with. You are only able to import 50 variables at once, so we're going to do total population and male population together, then female population, followed by home value. Eventually we will join them into one larger dataframe.

# %%
#male old and total
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'
url_str= 'https://api.census.gov/data/2014/acs/acs5?get=NAME,GEO_ID,B01001_001E,B01001_002E,B01001_003E,B01001_004E,B01001_005E,B01001_006E,B01001_007E,B01001_008E,B01001_009E,B01001_010E,B01001_011E,B01001_012E,B01001_013E,B01001_014E,B01001_015E,B01001_016E,B01001_017E,B01001_018E,B01001_019E,B01001_020E,B01001_021E,B01001_022E,B01001_023E,B01001_024E,B01001_025E&for=county:*&in=state:*&key='+api_key

predicates= {}
get_vars= ["NAME", "GEO_ID",'B01001_001E','B01001_020E','B01001_003E','B01001_004E','B01001_005E','B01001_006E','B01001_007E','B01001_008E','B01001_009E','B01001_010E','B01001_011E','B01001_012E','B01001_013E','B01001_014E','B01001_015E','B01001_016E','B01001_017E','B01001_018E','B01001_019E','B01001_020E','B01001_021E','B01001_022E','B01001_023E','B01001_024E','B01001_025E', 'state']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:*"
maleold= requests.get(url_str, params= predicates)

col_names = ['County', 'GEOID','total','mtotal','mu5','m5_9','m10_14','m15_17','m18_19','m20','m21','m22_24','m25_29','m30_34',
            'm35_39','m40_44','m45_49','m50_54','m55_59','m60_61','m62_64','m65_66','m67_69','m70_74','m75_79','m80_84','m85+', 'StateFIPS', 'ind']
maleold=pd.DataFrame(columns=col_names, data=maleold.json()[1:])

# %%
#male new and total
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'
url_str= 'https://api.census.gov/data/2019/acs/acs5?get=NAME,GEO_ID,B01001_001E,B01001_002E,B01001_003E,B01001_004E,B01001_005E,B01001_006E,B01001_007E,B01001_008E,B01001_009E,B01001_010E,B01001_011E,B01001_012E,B01001_013E,B01001_014E,B01001_015E,B01001_016E,B01001_017E,B01001_018E,B01001_019E,B01001_020E,B01001_021E,B01001_022E,B01001_023E,B01001_024E,B01001_025E&for=county:*&in=state:*&key='+api_key

predicates= {}
get_vars= ["NAME", "GEO_ID",'B01001_001E','B01001_020E','B01001_003E','B01001_004E','B01001_005E','B01001_006E','B01001_007E','B01001_008E','B01001_009E','B01001_010E','B01001_011E','B01001_012E','B01001_013E','B01001_014E','B01001_015E','B01001_016E','B01001_017E','B01001_018E','B01001_019E','B01001_020E','B01001_021E','B01001_022E','B01001_023E','B01001_024E','B01001_025E', 'state']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:*"
malenew= requests.get(url_str, params= predicates)

col_names = ['County', 'GEOID','total','mtotal','mu5','m5_9','m10_14','m15_17','m18_19','m20','m21','m22_24','m25_29','m30_34',
            'm35_39','m40_44','m45_49','m50_54','m55_59','m60_61','m62_64','m65_66','m67_69','m70_74','m75_79','m80_84','m85+', 'StateFIPS', 'ind']
malenew=pd.DataFrame(columns=col_names, data=malenew.json()[1:])

# %%
maleold.head(2)
# Out:
#                        County           GEOID  total mtotal  mu5 m5_9 m10_14  \
# 0  McPherson County, Nebraska  0500000US31117    426    214   21   11      6
# 1   Cheyenne County, Nebraska  0500000US31033  10044   5021  310  466    294
#
#   m15_17 m18_19 m20 m21 m22_24 m25_29 m30_34 m35_39 m40_44 m45_49 m50_54  \
# 0     12      3   0   0      1     17      7      8     18     21      7
# 1    196    106  43  61    168    352    304    383    251    325    384
#
#   m55_59 m60_61 m62_64 m65_66 m67_69 m70_74 m75_79 m80_84 m85+ StateFIPS  ind
# 0     30      4      5      8      2      5      6     10   12        31  117
# 1    399    142    151     81    146    127    161     96   75        31  033

# %%
malenew.head(2)
# Out:
#                      County           GEOID  total mtotal  mu5 m5_9 m10_14  \
# 0  Fayette County, Illinois  0500000US17051  21565  11469  621  621    636
# 1    Logan County, Illinois  0500000US17107  29003  14298  828  757    748
#
#   m15_17 m18_19  m20  m21 m22_24 m25_29 m30_34 m35_39 m40_44 m45_49 m50_54  \
# 0    417    254  156  226    438    812    718    800    703    768    825
# 1    544    497  218  190    588    924    910   1053    925    953    931
#
#   m55_59 m60_61 m62_64 m65_66 m67_69 m70_74 m75_79 m80_84 m85+ StateFIPS  ind
# 0    843    344    423    249    308    530    402    185  190        17  051
# 1   1018    378    588    344    393    545    416    200  350        17  107

# %%
#female old
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'
url_str= 'https://api.census.gov/data/2014/acs/acs5?get=NAME,GEO_ID,B01001_026E,B01001_027E,B01001_028E,B01001_029E,B01001_030E,B01001_031E,B01001_032E,B01001_033E,B01001_034E,B01001_035E,B01001_036E,B01001_037E,B01001_038E,B01001_039E,B01001_040E,B01001_041E,B01001_042E,B01001_043E,B01001_044E,B01001_045E,B01001_046E,B01001_047E,B01001_048E,B01001_049E&for=county:*&in=state:*&key='+api_key

predicates= {}
get_vars= ["NAME","GEO_ID",'B01001_026E','B01001_027E','B01001_028E','B01001_029E','B01001_030E','B01001_031E','B01001_032E','B01001_033E','B01001_034E','B01001_035E','B01001_036E','B01001_037E','B01001_038E','B01001_039E','B01001_040E','B01001_041E','B01001_042E','B01001_043E','B01001_044E','B01001_045E','B01001_046E','B01001_047E','B01001_048E','B01001_049E', 'state']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:*"
femaleold= requests.get(url_str, params= predicates)

col_names = ['County','GEOID','ftotal', 'fu5','f5_9','f10_14','f15_17','f18_19','f20','f21','f22_24','f25_29','f30_34',
            'f35_39','f40_44','f45_49','f50_54','f55_59','f60_61','f62_64','f65_66','f67_69','f70_74','f75_79','f80_84','f85+','StateFIPS','ind']
femaleold=pd.DataFrame(columns=col_names, data=femaleold.json()[1:])

# %%
#female new
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'
url_str= 'https://api.census.gov/data/2019/acs/acs5?get=NAME,GEO_ID,B01001_026E,B01001_027E,B01001_028E,B01001_029E,B01001_030E,B01001_031E,B01001_032E,B01001_033E,B01001_034E,B01001_035E,B01001_036E,B01001_037E,B01001_038E,B01001_039E,B01001_040E,B01001_041E,B01001_042E,B01001_043E,B01001_044E,B01001_045E,B01001_046E,B01001_047E,B01001_048E,B01001_049E&for=county:*&in=state:*&key='+api_key

predicates= {}
get_vars= ["NAME","GEO_ID",'B01001_026E','B01001_027E','B01001_028E','B01001_029E','B01001_030E','B01001_031E','B01001_032E','B01001_033E','B01001_034E','B01001_035E','B01001_036E','B01001_037E','B01001_038E','B01001_039E','B01001_040E','B01001_041E','B01001_042E','B01001_043E','B01001_044E','B01001_045E','B01001_046E','B01001_047E','B01001_048E','B01001_049E', 'state']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:*"
femalenew= requests.get(url_str, params= predicates)

col_names = ['County','GEOID','ftotal', 'fu5','f5_9','f10_14','f15_17','f18_19','f20','f21','f22_24','f25_29','f30_34',
            'f35_39','f40_44','f45_49','f50_54','f55_59','f60_61','f62_64','f65_66','f67_69','f70_74','f75_79','f80_84','f85+','StateFIPS','ind']
femalenew=pd.DataFrame(columns=col_names, data=femalenew.json()[1:])

# %%
femaleold.head(2)
# Out:
#                        County           GEOID ftotal  fu5 f5_9 f10_14 f15_17  \
# 0  McPherson County, Nebraska  0500000US31117    212   13   11     12      4
# 1   Cheyenne County, Nebraska  0500000US31033   5023  316  253    400    190
#
#   f18_19 f20 f21 f22_24 f25_29 f30_34 f35_39 f40_44 f45_49 f50_54 f55_59  \
# 0      3   0   0      5     15      5     16      4     30     28     10
# 1    104  16  28    145    335    351    235    303    363    417    362
#
#   f60_61 f62_64 f65_66 f67_69 f70_74 f75_79 f80_84 f85+ StateFIPS  ind
# 0      7      3     10      2      2     14      6   12        31  117
# 1    129    145    108    109    171    266    144  133        31  033

# %%
femalenew.head(2)
# Out:
#                      County           GEOID ftotal  fu5 f5_9 f10_14 f15_17  \
# 0  Fayette County, Illinois  0500000US17051  10096  564  497    711    387
# 1    Logan County, Illinois  0500000US17107  14705  725  718    784    503
#
#   f18_19  f20  f21 f22_24 f25_29 f30_34 f35_39 f40_44 f45_49 f50_54 f55_59  \
# 0    177   95  135    327    593    573    587    540    622    640    827
# 1    467  187  187    689   1058    952    927    794    838    878   1124
#
#   f60_61 f62_64 f65_66 f67_69 f70_74 f75_79 f80_84 f85+ StateFIPS  ind
# 0    215    412    200    339    572    474    315  294        17  051
# 1    353    545    380    455    642    455    294  750        17  107

# %%
#home value old
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'
url_str= 'https://api.census.gov/data/2014/acs/acs5?get=NAME,GEO_ID,B25077_001E&for=county:*&in=state:*&key='+api_key

predicates= {}
get_vars= ["NAME","GEO_ID",'B25077_001E', 'state']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:*"
homeold= requests.get(url_str, params= predicates)

col_names = ['County','GEOID','homevalue', 'state','ind']
homeold=pd.DataFrame(columns=col_names, data=homeold.json()[1:])

# %%
#home value new
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'
url_str= 'https://api.census.gov/data/2019/acs/acs5?get=NAME,GEO_ID,B25077_001E&for=county:*&in=state:*&key='+api_key

predicates= {}
get_vars= ["NAME","GEO_ID",'B25077_001E', 'state']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:*"
homenew= requests.get(url_str, params= predicates)

col_names = ['County','GEOID','homevalue', 'state','ind']
homenew=pd.DataFrame(columns=col_names, data=homenew.json()[1:])

# %%
homeold.head(2)
# Out:
#                        County           GEOID homevalue state  ind
# 0  McPherson County, Nebraska  0500000US31117    132700    31  117
# 1   Cheyenne County, Nebraska  0500000US31033    108400    31  033

# %%
homenew.head(2)
# Out:
#                      County           GEOID homevalue state  ind
# 0  Fayette County, Illinois  0500000US17051     88300    17  051
# 1    Logan County, Illinois  0500000US17107    103200    17  107

# %% [markdown]
# Join all of the "old" back together into one bigger df:

# %%
old = pd.merge(maleold, femaleold, how = 'inner', on = 'GEOID')

# %%
old = pd.merge(old, homeold, how = 'inner', on = 'GEOID')

# %% [markdown]
# Do the same for "new":

# %%
new = pd.merge(malenew, femalenew, how = 'inner', on = 'GEOID')

# %%
new = pd.merge(new, homenew, how = 'inner', on = 'GEOID')

# %% [markdown]
# Create something distinctive for the "old" data columns and then merge the two:

# %%
#for loop for renaming them with an O* for old at the beginning of each column
for col in old.columns:
    old.rename(columns = {col:'O*'+col}, inplace = True)

# %%
old.head()
# Out:
#                    O*County_x         O*GEOID O*total O*mtotal O*mu5 O*m5_9  \
# 0  McPherson County, Nebraska  0500000US31117     426      214    21     11
# 1   Cheyenne County, Nebraska  0500000US31033   10044     5021   310    466
# 2     Dawson County, Nebraska  0500000US31047   24205    12201   989   1069
# 3   Garfield County, Nebraska  0500000US31071    1954      969    42     59
# 4      Nance County, Nebraska  0500000US31125    3667     1840   115    118
#
#   O*m10_14 O*m15_17 O*m18_19 O*m20 O*m21 O*m22_24 O*m25_29 O*m30_34 O*m35_39  \
# 0        6       12        3     0     0        1       17        7        8
# 1      294      196      106    43    61      168      352      304      383
# 2      820      574      318   172   103      428      819      755      647
# 3       74       44        0     9     0       29       51       57       44
# 4      138       77       17    21    29       53       96      100       48
#
#   O*m40_44 O*m45_49 O*m50_54 O*m55_59 O*m60_61 O*m62_64 O*m65_66 O*m67_69  \
# 0       18       21        7       30        4        5        8        2
# 1      251      325      384      399      142      151       81      146
# 2      817      803      851      981      297      295      151      286
# 3       20       50       80       68       57       42       17       28
# 4      121      128      166      150       53      108       45       24
#
#   O*m70_74 O*m75_79 O*m80_84 O*m85+ O*StateFIPS_x O*ind_x  \
# 0        5        6       10     12            31     117
# 1      127      161       96     75            31     033
# 2      360      287      181    198            31     047
# 3       81       66       36     15            31     071
# 4       79       64       50     40            31     125
#
#                    O*County_y O*ftotal O*fu5 O*f5_9 O*f10_14 O*f15_17  \
# 0  McPherson County, Nebraska      212    13     11       12        4
# 1   Cheyenne County, Nebraska     5023   316    253      400      190
# 2     Dawson County, Nebraska    12004   861   1058      874      570
# 3   Garfield County, Nebraska      985    42    101       43       37
# 4      Nance County, Nebraska     1827   101     96      125       75
#
#   O*f18_19 O*f20 O*f21 O*f22_24 O*f25_29 O*f30_34 O*f35_39 O*f40_44 O*f45_49  \
# 0        3     0     0        5       15        5       16        4       30
# 1      104    16    28      145      335      351      235      303      363
# 2      299   115   103      480      705      726      613      809      682
# 3       13     0     0       36       36       42       42       33       58
# 4       48     5    17       46       80       89       65      129      114
#
#   O*f50_54 O*f55_59 O*f60_61 O*f62_64 O*f65_66 O*f67_69 O*f70_74 O*f75_79  \
# 0       28       10        7        3       10        2        2       14
# 1      417      362      129      145      108      109      171      266
# 2      762      743      270      413      149      313      442      459
# 3       84       85       29       24       33       51       52       60
# 4      142      142       70       68       34       70       62       89
#
#   O*f80_84 O*f85+ O*StateFIPS_y O*ind_y                    O*County  \
# 0        6     12            31     117  McPherson County, Nebraska
# 1      144    133            31     033   Cheyenne County, Nebraska
# 2      297    261            31     047     Dawson County, Nebraska
# 3       49     35            31     071   Garfield County, Nebraska
# 4       71     89            31     125      Nance County, Nebraska
#
#   O*homevalue O*state O*ind
# 0      132700      31   117
# 1      108400      31   033
# 2       89700      31   047
# 3       84800      31   071
# 4       71000      31   125

# %%
#rename the O*GEOID to the reverted column name to join on it
old = old.rename(columns = {'O*GEOID':'GEOID', 'O*County_x':'County'})

# %%
#make sure the datatypes are correct
new['GEOID'] = new['GEOID'].astype(str)
old['GEOID'] = old['GEOID'].astype(str)
new['County'] = new['County'].astype(str)
old['County'] = old['County'].astype(str)

# %%
data = pd.merge(new, old, on='County', how = 'inner')

# %% [markdown]
# Check out our datatypes and any extra columns from the join that are no longer necessary.

# %%
#set parameter to show all columns
pd.set_option('max_columns', None)

# %%
data.head()
# Out:
#                    County_x         GEOID_x   total  mtotal    mu5   m5_9  \
# 0  Fayette County, Illinois  0500000US17051   21565   11469    621    621
# 1    Logan County, Illinois  0500000US17107   29003   14298    828    757
# 2   Saline County, Illinois  0500000US17165   23994   11807    798    612
# 3     Lake County, Illinois  0500000US17097  701473  350466  20725  24406
# 4   Massac County, Illinois  0500000US17127   14219    6714    388    516
#
#   m10_14 m15_17 m18_19   m20   m21 m22_24 m25_29 m30_34 m35_39 m40_44 m45_49  \
# 0    636    417    254   156   226    438    812    718    800    703    768
# 1    748    544    497   218   190    588    924    910   1053    925    953
# 2    803    546    261    93   209    355    754    735    876    447    769
# 3  25733  16798  12229  6059  5339  16055  20443  19709  21358  22285  24147
# 4    344    247    132    24   104    251    388    344    361    462    451
#
#   m50_54 m55_59 m60_61 m62_64 m65_66 m67_69 m70_74 m75_79 m80_84  m85+  \
# 0    825    843    344    423    249    308    530    402    185   190
# 1    931   1018    378    588    344    393    545    416    200   350
# 2    790    766    416    474    382    388    488    365    263   217
# 3  25337  24931   9525  11855   7284   8795  11336   7488   4498  4131
# 4    462    471    171    330    118    205    393    258    193   101
#
#   StateFIPS_x ind_x                  County_y  ftotal    fu5   f5_9 f10_14  \
# 0          17   051  Fayette County, Illinois   10096    564    497    711
# 1          17   107    Logan County, Illinois   14705    725    718    784
# 2          17   165   Saline County, Illinois   12187    700    571    774
# 3          17   097     Lake County, Illinois  351007  19978  22550  25428
# 4          17   127   Massac County, Illinois    7505    403    712    325
#
#   f15_17 f18_19   f20   f21 f22_24 f25_29 f30_34 f35_39 f40_44 f45_49 f50_54  \
# 0    387    177    95   135    327    593    573    587    540    622    640
# 1    503    467   187   187    689   1058    952    927    794    838    878
# 2    392    193   152   132    290    821    718    785    573    754    875
# 3  15928   9600  4158  4224  14587  18301  19441  21434  23054  25021  26294
# 4    269    112    93    26    252    377    362    452    457    430    487
#
#   f55_59 f60_61 f62_64 f65_66 f67_69 f70_74 f75_79 f80_84  f85+ StateFIPS_y  \
# 0    827    215    412    200    339    572    474    315   294          17
# 1   1124    353    545    380    455    642    455    294   750          17
# 2    872    488    415    304    387    692    449    347   503          17
# 3  25545   9903  12754   7949   9604  12364   8595   6080  8215          17
# 4    469    319    266    226    207    408    269    311   273          17
#
#   ind_y                    County homevalue state  ind         GEOID_y  \
# 0   051  Fayette County, Illinois     88300    17  051  0500000US17051
# 1   107    Logan County, Illinois    103200    17  107  0500000US17107
# 2   165   Saline County, Illinois     73800    17  165  0500000US17165
# 3   097     Lake County, Illinois    265100    17  097  0500000US17097
# 4   127   Massac County, Illinois     83600    17  127  0500000US17127
#
#   O*total O*mtotal  O*mu5 O*m5_9 O*m10_14 O*m15_17 O*m18_19 O*m20 O*m21  \
# 0   22041    11630    610    679      716      445      301   155   229
# 1   30047    15258    783    824      799      528      594   226   158
# 2   24876    12067    740    899      654      557      311   274   179
# 3  703170   350905  22414  26369    28358    17758    12603  5363  5072
# 4   15148     7258    398    518      485      272      166    66   108
#
#   O*m22_24 O*m25_29 O*m30_34 O*m35_39 O*m40_44 O*m45_49 O*m50_54 O*m55_59  \
# 0      485      827      769      795      848      853      859      881
# 1      865     1155     1169     1111      903     1066     1129     1008
# 2      332      761      697      568      831      809      870      723
# 3    14241    20040    20113    22290    24118    26962    27730    23474
# 4      198      341      363      491      472      539      546      565
#
#   O*m60_61 O*m62_64 O*m65_66 O*m67_69 O*m70_74 O*m75_79 O*m80_84 O*m85+  \
# 0      207      341      233      269      390      322      215    201
# 1      417      465      390      318      441      387      243    279
# 2      282      595      321      272      561      330      276    225
# 3     7803    11077     5422     7123     8937     5849     4207   3582
# 4      137      333      218      144      366      181      194    157
#
#   O*StateFIPS_x O*ind_x                O*County_y O*ftotal  O*fu5 O*f5_9  \
# 0            17     051  Fayette County, Illinois    10411    616    708
# 1            17     107    Logan County, Illinois    14789    714    824
# 2            17     165   Saline County, Illinois    12809    736    799
# 3            17     097     Lake County, Illinois   352265  21597  25095
# 4            17     127   Massac County, Illinois     7890    391    445
#
#   O*f10_14 O*f15_17 O*f18_19 O*f20 O*f21 O*f22_24 O*f25_29 O*f30_34 O*f35_39  \
# 0      629      486      220   119   139      347      588      580      514
# 1      748      503      463   137   139      703      906      975      829
# 2      749      458      289   203   129      441      719      681      511
# 3    26896    16630     9918  4135  3755    12095    18496    20442    22654
# 4      644      233      150   128    20      250      421      436      465
#
#   O*f40_44 O*f45_49 O*f50_54 O*f55_59 O*f60_61 O*f62_64 O*f65_66 O*f67_69  \
# 0      657      675      785      756      220      359      284      343
# 1     1012      975     1101      922      360      623      287      381
# 2      839      886      909      848      299      630      324      443
# 3    25929    28060    28714    23989     8817    10764     6340     7494
# 4      471      514      600      622      222      251      181      282
#
#   O*f70_74 O*f75_79 O*f80_84 O*f85+ O*StateFIPS_y O*ind_y  \
# 0      378      376      273    359            17     051
# 1      660      434      432    661            17     107
# 2      577      546      385    408            17     165
# 3     9876     6965     6238   7366            17     097
# 4      328      283      279    274            17     127
#
#                    O*County O*homevalue O*state O*ind
# 0  Fayette County, Illinois       81700      17   051
# 1    Logan County, Illinois       97500      17   107
# 2   Saline County, Illinois       71100      17   165
# 3     Lake County, Illinois      247300      17   097
# 4   Massac County, Illinois       83200      17   127

# %% [markdown]
# Drop the indices and extra County name column, rename the one you're going to keep, then convert all numeric columns to int64 as we're going to be performing mathematical operations on them.

# %%
#drop the indices and extra state name
data = data.drop(columns=['ind_x','County_y','StateFIPS_y','ind_y','County','state','ind','GEOID_y','O*StateFIPS_x','O*ind_x','O*County_y','O*StateFIPS_y','O*ind_y','O*ind','O*County','O*state'])

# %%
data = data.rename(columns={'County_x':'County','GEOID_x':'GEOID', 'StateFIPS_x':'StateFIPS'})

# %%
#convert all numeric columns to integers
cols = ['total','mtotal','mu5','m5_9','m10_14','m15_17','m18_19','m20','m21','m22_24','m25_29','m30_34',
        'm35_39','m40_44','m45_49','m50_54','m55_59','m60_61','m62_64','m65_66','m67_69','m70_74','m75_79',
        'm80_84','m85+','ftotal', 'fu5','f5_9','f10_14','f15_17','f18_19','f20','f21','f22_24','f25_29',
        'f30_34','f35_39','f40_44','f45_49','f50_54','f55_59','f60_61','f62_64','f65_66','f67_69','f70_74',
        'f75_79','f80_84','f85+','homevalue','O*total','O*mtotal','O*mu5','O*m5_9','O*m10_14','O*m15_17','O*m18_19','O*m20',
        'O*m21','O*m22_24','O*m25_29','O*m30_34','O*m35_39','O*m40_44','O*m45_49','O*m50_54','O*m55_59','O*m60_61','O*m62_64','O*m65_66',
        'O*m67_69','O*m70_74','O*m75_79','O*m80_84','O*m85+','O*ftotal', 'O*fu5','O*f5_9','O*f10_14','O*f15_17','O*f18_19','O*f20','O*f21',
        'O*f22_24','O*f25_29','O*f30_34','O*f35_39','O*f40_44','O*f45_49','O*f50_54','O*f55_59','O*f60_61','O*f62_64','O*f65_66','O*f67_69',
        'O*f70_74','O*f75_79','O*f80_84','O*f85+','O*homevalue']

data[cols]=data[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %% [markdown]
# Check that the last few steps were effective.

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3218 entries, 0 to 3217
# Data columns (total 103 columns):
#  #    Column       Dtype
# ---   ------       -----
#  0    County       object
#  1    GEOID        object
#  2    total        int64
#  3    mtotal       int64
#  4    mu5          int64
#  5    m5_9         int64
#  6    m10_14       int64
#  7    m15_17       int64
#  8    m18_19       int64
#  9    m20          int64
#  10   m21          int64
#  11   m22_24       int64
#  12   m25_29       int64
#  13   m30_34       int64
#  14   m35_39       int64
#  15   m40_44       int64
#  16   m45_49       int64
#  17   m50_54       int64
#  18   m55_59       int64
#  19   m60_61       int64
#  20   m62_64       int64
#  21   m65_66       int64
#  22   m67_69       int64
#  23   m70_74       int64
#  24   m75_79       int64
#  25   m80_84       int64
#  26   m85+         int64
#  27   StateFIPS    object
#  28   ftotal       int64
#  29   fu5          int64
#  30   f5_9         int64
#  31   f10_14       int64
#  32   f15_17       int64
#  33   f18_19       int64
#  34   f20          int64
#  35   f21          int64
#  36   f22_24       int64
#  37   f25_29       int64
#  38   f30_34       int64
#  39   f35_39       int64
#  40   f40_44       int64
#  41   f45_49       int64
#  42   f50_54       int64
#  43   f55_59       int64
#  44   f60_61       int64
#  45   f62_64       int64
#  46   f65_66       int64
#  47   f67_69       int64
#  48   f70_74       int64
#  49   f75_79       int64
#  50   f80_84       int64
#  51   f85+         int64
#  52   homevalue    int64
#  53   O*total      int64
#  54   O*mtotal     int64
#  55   O*mu5        int64
#  56   O*m5_9       int64
#  57   O*m10_14     int64
#  58   O*m15_17     int64
#  59   O*m18_19     int64
#  60   O*m20        int64
#  61   O*m21        int64
#  62   O*m22_24     int64
#  63   O*m25_29     int64
#  64   O*m30_34     int64
#  65   O*m35_39     int64
#  66   O*m40_44     int64
#  67   O*m45_49     int64
#  68   O*m50_54     int64
#  69   O*m55_59     int64
#  70   O*m60_61     int64
#  71   O*m62_64     int64
#  72   O*m65_66     int64
#  73   O*m67_69     int64
#  74   O*m70_74     int64
#  75   O*m75_79     int64
#  76   O*m80_84     int64
#  77   O*m85+       int64
#  78   O*ftotal     int64
#  79   O*fu5        int64
#  80   O*f5_9       int64
#  81   O*f10_14     int64
#  82   O*f15_17     int64
#  83   O*f18_19     int64
#  84   O*f20        int64
#  85   O*f21        int64
#  86   O*f22_24     int64
#  87   O*f25_29     int64
#  88   O*f30_34     int64
#  89   O*f35_39     int64
#  90   O*f40_44     int64
#  91   O*f45_49     int64
#  92   O*f50_54     int64
#  93   O*f55_59     int64
#  94   O*f60_61     int64
#  95   O*f62_64     int64
#  96   O*f65_66     int64
#  97   O*f67_69     int64
#  98   O*f70_74     int64
#  99   O*f75_79     int64
#  100  O*f80_84     int64
#  101  O*f85+       int64
#  102  O*homevalue  int64
# dtypes: int64(100), object(3)
# memory usage: 2.6+ MB

# %% [markdown]
# Create columns of totals for each one of these age groups.

# %%
#create totals columns for "new":
data['tu5'] = data['mu5']+data['fu5']
data['t5_9'] = data['m5_9']+data['f5_9']
data['t10_14'] = data['m10_14']+data['f10_14']
data['t15_17'] = data['m15_17']+data['f15_17']
data['t18_19'] = data['m18_19']+data['f18_19']
data['t20'] = data['m20']+data['f20']
data['t21'] = data['m21']+data['f21']
data['t22_24'] = data['m22_24']+data['f22_24']
data['t25_29'] = data['m25_29']+data['f25_29']
data['t30_34'] = data['m30_34']+data['f30_34']
data['t35_39'] = data['m35_39']+data['f35_39']
data['t40_44'] = data['m40_44']+data['f40_44']
data['t45_49'] = data['m45_49']+data['f45_49']
data['t50_54'] = data['m50_54']+data['f50_54']
data['t55_59'] = data['m55_59']+data['f55_59']
data['t60_61'] = data['m60_61']+data['f60_61']
data['t62_64'] = data['m62_64']+data['f62_64']
data['t65_66'] = data['m65_66']+data['f65_66']
data['t67_69'] = data['m67_69']+data['f67_69']
data['t70_74'] = data['m70_74']+data['f70_74']
data['t75_79'] = data['m75_79']+data['f75_79']
data['t80_84'] = data['m80_84']+data['f80_84']
data['t85+'] = data['m85+']+data['f85+']

data = data.copy()

# %%
#do the same for "old":
data['O*tu5'] = data['O*mu5']+data['O*fu5']
data['O*t5_9'] = data['O*m5_9']+data['O*f5_9']
data['O*t10_14'] = data['O*m10_14']+data['O*f10_14']
data['O*t15_17'] = data['O*m15_17']+data['O*f15_17']
data['O*t18_19'] = data['O*m18_19']+data['O*f18_19']
data['O*t20'] = data['O*m20']+data['O*f20']
data['O*t21'] = data['O*m21']+data['O*f21']
data['O*t22_24'] = data['O*m22_24']+data['O*f22_24']
data['O*t25_29'] = data['O*m25_29']+data['O*f25_29']
data['O*t30_34'] = data['O*m30_34']+data['O*f30_34']
data['O*t35_39'] = data['O*m35_39']+data['O*f35_39']
data['O*t40_44'] = data['O*m40_44']+data['O*f40_44']
data['O*t45_49'] = data['O*m45_49']+data['O*f45_49']
data['O*t50_54'] = data['O*m50_54']+data['O*f50_54']
data['O*t55_59'] = data['O*m55_59']+data['O*f55_59']
data['O*t60_61'] = data['O*m60_61']+data['O*f60_61']
data['O*t62_64'] = data['O*m62_64']+data['O*f62_64']
data['O*t65_66'] = data['O*m65_66']+data['O*f65_66']
data['O*t67_69'] = data['O*m67_69']+data['O*f67_69']
data['O*t70_74'] = data['O*m70_74']+data['O*f70_74']
data['O*t75_79'] = data['O*m75_79']+data['O*f75_79']
data['O*t80_84'] = data['O*m80_84']+data['O*f80_84']
data['O*t85+'] = data['O*m85+']+data['O*f85+']

data = data.copy()

# %% [markdown]
# ## Create groups for analysis. Since we're looking at ageing services, it makes sense to group people into some rough "stage of life" that is predicated on services provided to them or their position in the workforce.
#
# ###### So we're going to do:
# - under 18
# - 18 - 64
# - 65+
#
# Note that we're also eliminating the gender divide, we can always come back and disaggregate this but it doesn't seem particularly relevant now.

# %%
#child
data['child'] = data['tu5']+data['t5_9']+data['t10_14']+data['t15_17']
data['O*child'] = data['O*tu5']+data['O*t5_9']+data['O*t10_14']+data['O*t15_17']
#taxbase
data['taxbase'] = data['t18_19']+data['t20']+data['t21']+data['t22_24']+data['t25_29']+data['t30_34']+data['t35_39']+data['t40_44']+data['t45_49']+data['t50_54']+data['t55_59']+data['t60_61']+data['t62_64']
data['O*taxbase'] = data['O*t18_19']+data['O*t20']+data['O*t21']+data['O*t22_24']+data['O*t25_29']+data['O*t30_34']+data['O*t35_39']+data['O*t40_44']+data['O*t45_49']+data['O*t50_54']+data['O*t55_59']+data['O*t60_61']+data['O*t62_64']
#over 65
data['O65'] = data['t65_66']+data['t67_69']+data['t70_74']+data['t75_79']+data['t80_84']+data['t85+']
data['O*O65'] = data['O*t65_66']+data['O*t67_69']+data['O*t70_74']+data['O*t75_79']+data['O*t80_84']+data['O*t85+']

data = data.copy()

# %% [markdown]
# Make these groups into shares of the total.

# %%
data['Pchild']=round(data['child']*100/data['total'],1)
data['Ptaxbase']=round(data['taxbase']*100/data['total'],1)
data['PO65']=round(data['O65']*100/data['total'],1)
data['O*Pchild']=round(data['O*child']*100/data['O*total'],1)
data['O*Ptaxbase']=round(data['O*taxbase']*100/data['O*total'],1)
data['O*PO65']=round(data['O*O65']*100/data['O*total'],1)

data = data.copy()

# %%
data.head(2)
# Out:
#                      County           GEOID  total  mtotal  mu5  m5_9  m10_14  \
# 0  Fayette County, Illinois  0500000US17051  21565   11469  621   621     636
# 1    Logan County, Illinois  0500000US17107  29003   14298  828   757     748
#
#    m15_17  m18_19  m20  m21  m22_24  m25_29  m30_34  m35_39  m40_44  m45_49  \
# 0     417     254  156  226     438     812     718     800     703     768
# 1     544     497  218  190     588     924     910    1053     925     953
#
#    m50_54  m55_59  m60_61  m62_64  m65_66  m67_69  m70_74  m75_79  m80_84  \
# 0     825     843     344     423     249     308     530     402     185
# 1     931    1018     378     588     344     393     545     416     200
#
#    m85+ StateFIPS  ftotal  fu5  f5_9  f10_14  f15_17  f18_19  f20  f21  \
# 0   190        17   10096  564   497     711     387     177   95  135
# 1   350        17   14705  725   718     784     503     467  187  187
#
#    f22_24  f25_29  f30_34  f35_39  f40_44  f45_49  f50_54  f55_59  f60_61  \
# 0     327     593     573     587     540     622     640     827     215
# 1     689    1058     952     927     794     838     878    1124     353
#
#    f62_64  f65_66  f67_69  f70_74  f75_79  f80_84  f85+  homevalue  O*total  \
# 0     412     200     339     572     474     315   294      88300    22041
# 1     545     380     455     642     455     294   750     103200    30047
#
#    O*mtotal  O*mu5  O*m5_9  O*m10_14  O*m15_17  O*m18_19  O*m20  O*m21  \
# 0     11630    610     679       716       445       301    155    229
# 1     15258    783     824       799       528       594    226    158
#
#    O*m22_24  O*m25_29  O*m30_34  O*m35_39  O*m40_44  O*m45_49  O*m50_54  \
# 0       485       827       769       795       848       853       859
# 1       865      1155      1169      1111       903      1066      1129
#
#    O*m55_59  O*m60_61  O*m62_64  O*m65_66  O*m67_69  O*m70_74  O*m75_79  \
# 0       881       207       341       233       269       390       322
# 1      1008       417       465       390       318       441       387
#
#    O*m80_84  O*m85+  O*ftotal  O*fu5  O*f5_9  O*f10_14  O*f15_17  O*f18_19  \
# 0       215     201     10411    616     708       629       486       220
# 1       243     279     14789    714     824       748       503       463
#
#    O*f20  O*f21  O*f22_24  O*f25_29  O*f30_34  O*f35_39  O*f40_44  O*f45_49  \
# 0    119    139       347       588       580       514       657       675
# 1    137    139       703       906       975       829      1012       975
#
#    O*f50_54  O*f55_59  O*f60_61  O*f62_64  O*f65_66  O*f67_69  O*f70_74  \
# 0       785       756       220       359       284       343       378
# 1      1101       922       360       623       287       381       660
#
#    O*f75_79  O*f80_84  O*f85+  O*homevalue   tu5  t5_9  t10_14  t15_17  \
# 0       376       273     359        81700  1185  1118    1347     804
# 1       434       432     661        97500  1553  1475    1532    1047
#
#    t18_19  t20  t21  t22_24  t25_29  t30_34  t35_39  t40_44  t45_49  t50_54  \
# 0     431  251  361     765    1405    1291    1387    1243    1390    1465
# 1     964  405  377    1277    1982    1862    1980    1719    1791    1809
#
#    t55_59  t60_61  t62_64  t65_66  t67_69  t70_74  t75_79  t80_84  t85+  \
# 0    1670     559     835     449     647    1102     876     500   484
# 1    2142     731    1133     724     848    1187     871     494  1100
#
#    O*tu5  O*t5_9  O*t10_14  O*t15_17  O*t18_19  O*t20  O*t21  O*t22_24  \
# 0   1226    1387      1345       931       521    274    368       832
# 1   1497    1648      1547      1031      1057    363    297      1568
#
#    O*t25_29  O*t30_34  O*t35_39  O*t40_44  O*t45_49  O*t50_54  O*t55_59  \
# 0      1415      1349      1309      1505      1528      1644      1637
# 1      2061      2144      1940      1915      2041      2230      1930
#
#    O*t60_61  O*t62_64  O*t65_66  O*t67_69  O*t70_74  O*t75_79  O*t80_84  \
# 0       427       700       517       612       768       698       488
# 1       777      1088       677       699      1101       821       675
#
#    O*t85+  child  O*child  taxbase  O*taxbase   O65  O*O65  Pchild  Ptaxbase  \
# 0     560   4454     4889    13053      13509  4058   3643    20.7      60.5
# 1     940   5607     5723    18172      19411  5224   4913    19.3      62.7
#
#    PO65  O*Pchild  O*Ptaxbase  O*PO65
# 0  18.8      22.2        61.3    16.5
# 1  18.0      19.0        64.6    16.4

# %% [markdown]
# Make a separate dataframe of only these created groups and their shares

# %%
data = data[['County', 'GEOID', 'StateFIPS','total', 'child', 'taxbase', 'O65', 
           'Pchild', 'Ptaxbase', 'PO65', 'homevalue', 'O*total','O*child', 'O*taxbase', 'O*O65', 
           'O*Pchild', 'O*Ptaxbase', 'O*PO65', 'O*homevalue']]

# %%
data.head()
# Out:
#                      County           GEOID StateFIPS   total   child  \
# 0  Fayette County, Illinois  0500000US17051        17   21565    4454
# 1    Logan County, Illinois  0500000US17107        17   29003    5607
# 2   Saline County, Illinois  0500000US17165        17   23994    5196
# 3     Lake County, Illinois  0500000US17097        17  701473  171546
# 4   Massac County, Illinois  0500000US17127        17   14219    3204
#
#    taxbase    O65  Pchild  Ptaxbase  PO65  homevalue  O*total  O*child  \
# 0    13053   4058    20.7      60.5  18.8      88300    22041     4889
# 1    18172   5224    19.3      62.7  18.0     103200    30047     5723
# 2    14013   4785    21.7      58.4  19.9      73800    24876     5592
# 3   433588  96339    24.5      61.8  13.7     265100   703170   185117
# 4     8053   2962    22.5      56.6  20.8      83600    15148     3386
#
#    O*taxbase  O*O65  O*Pchild  O*Ptaxbase  O*PO65  O*homevalue
# 0      13509   3643      22.2        61.3    16.5        81700
# 1      19411   4913      19.0        64.6    16.4        97500
# 2      14616   4668      22.5        58.8    18.8        71100
# 3     438654  79399      26.3        62.4    11.3       247300
# 4       8875   2887      22.4        58.6    19.1        83200

# %% [markdown]
# Let's split the full GEOID so that we have the CBSA FIPS, let's also split up the CBSA names so that we have the name, state, and Metro or Micro Area designation. Start with the geography name.

# %%
# Split the County column at the comma then name the new column as the first column you index into
name = data['County'].str.split(pat = ',', expand = True)
name
# Out:
#                     0            1
# 0      Fayette County     Illinois
# 1        Logan County     Illinois
# 2       Saline County     Illinois
# 3         Lake County     Illinois
# 4       Massac County     Illinois
# ...               ...          ...
# 3213  Crockett County    Tennessee
# 3214      Lake County    Tennessee
# 3215      Knox County    Tennessee
# 3216    Benton County   Washington
# 3217     Clark County   Washington
#
# [3218 rows x 2 columns]

# %%
data['CountyOnly'] = name[0]
data['State'] = name[1]

# %% [markdown]
# Now we're going to split the GEOIDs.

# %%
data['CountyFIPS'] = data['GEOID'].str.slice(start = 9)

# %%
data.head()
# Out:
#                      County           GEOID StateFIPS   total   child  \
# 0  Fayette County, Illinois  0500000US17051        17   21565    4454
# 1    Logan County, Illinois  0500000US17107        17   29003    5607
# 2   Saline County, Illinois  0500000US17165        17   23994    5196
# 3     Lake County, Illinois  0500000US17097        17  701473  171546
# 4   Massac County, Illinois  0500000US17127        17   14219    3204
#
#    taxbase    O65  Pchild  Ptaxbase  PO65  homevalue  O*total  O*child  \
# 0    13053   4058    20.7      60.5  18.8      88300    22041     4889
# 1    18172   5224    19.3      62.7  18.0     103200    30047     5723
# 2    14013   4785    21.7      58.4  19.9      73800    24876     5592
# 3   433588  96339    24.5      61.8  13.7     265100   703170   185117
# 4     8053   2962    22.5      56.6  20.8      83600    15148     3386
#
#    O*taxbase  O*O65  O*Pchild  O*Ptaxbase  O*PO65  O*homevalue  \
# 0      13509   3643      22.2        61.3    16.5        81700
# 1      19411   4913      19.0        64.6    16.4        97500
# 2      14616   4668      22.5        58.8    18.8        71100
# 3     438654  79399      26.3        62.4    11.3       247300
# 4       8875   2887      22.4        58.6    19.1        83200
#
#        CountyOnly      State CountyFIPS
# 0  Fayette County   Illinois      17051
# 1    Logan County   Illinois      17107
# 2   Saline County   Illinois      17165
# 3     Lake County   Illinois      17097
# 4   Massac County   Illinois      17127

# %% [markdown]
# # Now we start thinking about the kinds of change we want to look at.
#
# With the measures I think the two most sensical ways to look at things are: percent change in the raw numbers, and change in population share.
#
# First let's create the percent change:

# %%
data['O65percchange'] = round((data['O65'] - data['O*O65'])*100/data['O*O65'], 2)
data['taxbasepercchange'] = round((data['taxbase'] - data['O*taxbase'])*100/data['O*taxbase'], 2)
data['childpercchange'] = round((data['child'] - data['O*child'])*100/data['O*child'], 2)
data['totalpercchange'] = round((data['total']-data['O*total'])*100/data['O*total'], 2)
data['homepercchange'] = round((data['homevalue']-data['O*homevalue'])*100/data['O*homevalue'], 2)

# %% [markdown]
# Now change in share and real change:

# %%
data['O65sharechange'] = data['PO65'] - data['O*PO65']
data['taxbasesharechange'] = data['Ptaxbase'] - data['O*Ptaxbase']
data['childsharechange'] = data['Pchild'] - data['O*Pchild']
data['O65realchange'] = data['O65'] - data['O*O65']
data['taxbaserealchange'] = data['taxbase'] - data['O*taxbase']
data['childrealchange'] = data['child'] - data['O*child']
data['totalrealchange']= data['total'] - data['O*total']
data['homerealchange'] = data['homevalue'] - data['O*homevalue']

# %%
data.head()
# Out:
#                      County           GEOID StateFIPS   total   child  \
# 0  Fayette County, Illinois  0500000US17051        17   21565    4454
# 1    Logan County, Illinois  0500000US17107        17   29003    5607
# 2   Saline County, Illinois  0500000US17165        17   23994    5196
# 3     Lake County, Illinois  0500000US17097        17  701473  171546
# 4   Massac County, Illinois  0500000US17127        17   14219    3204
#
#    taxbase    O65  Pchild  Ptaxbase  PO65  homevalue  O*total  O*child  \
# 0    13053   4058    20.7      60.5  18.8      88300    22041     4889
# 1    18172   5224    19.3      62.7  18.0     103200    30047     5723
# 2    14013   4785    21.7      58.4  19.9      73800    24876     5592
# 3   433588  96339    24.5      61.8  13.7     265100   703170   185117
# 4     8053   2962    22.5      56.6  20.8      83600    15148     3386
#
#    O*taxbase  O*O65  O*Pchild  O*Ptaxbase  O*PO65  O*homevalue  \
# 0      13509   3643      22.2        61.3    16.5        81700
# 1      19411   4913      19.0        64.6    16.4        97500
# 2      14616   4668      22.5        58.8    18.8        71100
# 3     438654  79399      26.3        62.4    11.3       247300
# 4       8875   2887      22.4        58.6    19.1        83200
#
#        CountyOnly      State CountyFIPS  O65percchange  taxbasepercchange  \
# 0  Fayette County   Illinois      17051          11.39              -3.38
# 1    Logan County   Illinois      17107           6.33              -6.38
# 2   Saline County   Illinois      17165           2.51              -4.13
# 3     Lake County   Illinois      17097          21.34              -1.15
# 4   Massac County   Illinois      17127           2.60              -9.26
#
#    childpercchange  totalpercchange  homepercchange  O65sharechange  \
# 0            -8.90            -2.16            8.08             2.3
# 1            -2.03            -3.47            5.85             1.6
# 2            -7.08            -3.55            3.80             1.1
# 3            -7.33            -0.24            7.20             2.4
# 4            -5.38            -6.13            0.48             1.7
#
#    taxbasesharechange  childsharechange  O65realchange  taxbaserealchange  \
# 0                -0.8              -1.5            415               -456
# 1                -1.9               0.3            311              -1239
# 2                -0.4              -0.8            117               -603
# 3                -0.6              -1.8          16940              -5066
# 4                -2.0               0.1             75               -822
#
#    childrealchange  totalrealchange  homerealchange
# 0             -435             -476            6600
# 1             -116            -1044            5700
# 2             -396             -882            2700
# 3           -13571            -1697           17800
# 4             -182             -929             400

# %%
#index into where the Nashville MSA is to check the rankings out
nash = data.loc[data['County'] == 'Davidson County, Tennessee'].reset_index(drop = True)

# %%
nash
# Out:
#                        County           GEOID StateFIPS   total   child  \
# 0  Davidson County, Tennessee  0500000US47037        47  687488  145006
#
#    taxbase    O65  Pchild  Ptaxbase  PO65  homevalue  O*total  O*child  \
# 0   460275  82207    21.1      67.0  12.0     241700   648048   140485
#
#    O*taxbase  O*O65  O*Pchild  O*Ptaxbase  O*PO65  O*homevalue  \
# 0     438161  69402      21.7        67.6    10.7       167400
#
#         CountyOnly       State CountyFIPS  O65percchange  taxbasepercchange  \
# 0  Davidson County   Tennessee      47037          18.45               5.05
#
#    childpercchange  totalpercchange  homepercchange  O65sharechange  \
# 0             3.22             6.09           44.38             1.3
#
#    taxbasesharechange  childsharechange  O65realchange  taxbaserealchange  \
# 0                -0.6              -0.6          12805              22114
#
#    childrealchange  totalrealchange  homerealchange
# 0             4521            39440           74300

# %%
print("The following numbers are Nashville's percent growth in a 5 year over 5 year period for total elderly population, then the share change between the 2014 and 2019 periods:")
print('______________________________________________________________________________')
print(nash['O65percchange'])
print(nash['O65sharechange'])
print("The following number are Nashville's percent growth in a 5 year over 5 year period for total tax base population, then the share change between the 2014 and 2019 periods:")
print('______________________________________________________________________________')
print(nash['taxbasepercchange'])
print(nash['taxbasesharechange'])
print("The following number are Nashville's percent growth in a 5 year over 5 year period for total child population, then the share change between the 2014 and 2019 periods:")
print('______________________________________________________________________________')
print(nash['childpercchange'])
print(nash['childsharechange'])
# Out:
# The following numbers are Nashville's percent growth in a 5 year over 5 year period for total elderly population, then the share change between the 2014 and 2019 periods:
# ______________________________________________________________________________
# 0    18.45
# Name: O65percchange, dtype: float64
# 0    1.3
# Name: O65sharechange, dtype: float64
# The following number are Nashville's percent growth in a 5 year over 5 year period for total tax base population, then the share change between the 2014 and 2019 periods:
# ______________________________________________________________________________
# 0    5.05
# Name: taxbasepercchange, dtype: float64
# 0   -0.6
# Name: taxbasesharechange, dtype: float64
# The following number are Nashville's percent growth in a 5 year over 5 year period for total child population, then the share change between the 2014 and 2019 periods:
# ______________________________________________________________________________
# 0    3.22
# Name: childpercchange, dtype: float64
# 0   -0.6
# Name: childsharechange, dtype: float64

# %%
data.corr()
# Out:
#                        total     child   taxbase       O65    Pchild  \
# total               1.000000  0.994362  0.999419  0.983368  0.036531
# child               0.994362  1.000000  0.992357  0.965882  0.070053
# taxbase             0.999419  0.992357  1.000000  0.979850  0.033155
# O65                 0.983368  0.965882  0.979850  1.000000 -0.004111
# Pchild              0.036531  0.070053  0.033155 -0.004111  1.000000
# Ptaxbase            0.217196  0.208437  0.224010  0.194356 -0.224562
# PO65               -0.211300 -0.229173 -0.214519 -0.161321 -0.564632
# homevalue           0.009970  0.009749  0.009758  0.011013  0.061614
# O*total             0.999240  0.991860  0.998926  0.984273  0.033326
# O*child             0.995580  0.998775  0.993947  0.969377  0.064632
# O*taxbase           0.998458  0.989475  0.999227  0.981210  0.029060
# O*O65               0.979518  0.960071  0.976121  0.998924 -0.006601
# O*Pchild            0.055831  0.089734  0.051871  0.016670  0.904627
# O*Ptaxbase          0.193965  0.182301  0.201042  0.175352 -0.279310
# O*PO65             -0.213302 -0.229683 -0.216380 -0.166351 -0.465878
# O*homevalue         0.007789  0.007581  0.007640  0.008585  0.103931
# O65percchange       0.128440  0.131934  0.127243  0.124498 -0.071997
# taxbasepercchange   0.209619  0.219071  0.206593  0.201911  0.212440
# childpercchange     0.068192  0.074279  0.067261  0.060501  0.305602
# totalpercchange     0.201915  0.209414  0.198189  0.200816  0.187348
# homepercchange      0.005624  0.005552  0.005467  0.006291 -0.016732
# O65sharechange     -0.030893 -0.038126 -0.031839 -0.013852 -0.371907
# taxbasesharechange  0.068532  0.074600  0.068400  0.057225  0.110191
# childsharechange   -0.041844 -0.041041 -0.040692 -0.047214  0.265407
# O65realchange       0.967329  0.961038  0.963292  0.968425  0.009427
# taxbaserealchange   0.556484  0.593420  0.552807  0.496786  0.104596
# childrealchange    -0.247237 -0.200133 -0.254158 -0.285924  0.091601
# totalrealchange     0.677535  0.706683  0.672116  0.635076  0.084717
# homerealchange      0.006309  0.006204  0.006158  0.006987 -0.016808
#
#                     Ptaxbase      PO65  homevalue   O*total   O*child  \
# total               0.217196 -0.211300   0.009970  0.999240  0.995580
# child               0.208437 -0.229173   0.009749  0.991860  0.998775
# taxbase             0.224010 -0.214519   0.009758  0.998926  0.993947
# O65                 0.194356 -0.161321   0.011013  0.984273  0.969377
# Pchild             -0.224562 -0.564632   0.061614  0.033326  0.064632
# Ptaxbase            1.000000 -0.677400  -0.039155  0.216063  0.206098
# PO65               -0.677400  1.000000  -0.013345 -0.207913 -0.223089
# homevalue          -0.039155 -0.013345   1.000000  0.009973  0.009703
# O*total             0.216063 -0.207913   0.009973  1.000000  0.994843
# O*child             0.206098 -0.223089   0.009703  0.994843  1.000000
# O*taxbase           0.223325 -0.210842   0.009820  0.999465  0.992711
# O*O65               0.190846 -0.156462   0.010996  0.981887  0.965077
# O*Pchild           -0.124669 -0.577254   0.129285  0.052683  0.085750
# O*Ptaxbase          0.908590 -0.558706  -0.108061  0.193224  0.179948
# O*PO65             -0.695690  0.940877  -0.007354 -0.210204 -0.224526
# O*homevalue        -0.100934  0.007042   0.707055  0.007800  0.007554
# O65percchange       0.246329 -0.154344  -0.245789  0.121789  0.125688
# taxbasepercchange   0.312355 -0.425072   0.057291  0.197687  0.205761
# childpercchange    -0.080501 -0.162684  -0.268372  0.061399  0.064380
# totalpercchange     0.185745 -0.298928   0.001871  0.188699  0.194251
# homepercchange      0.045172 -0.025633   0.707001  0.005630  0.005524
# O65sharechange     -0.066038  0.336869  -0.018953 -0.029504 -0.034496
# taxbasesharechange  0.279792 -0.320025   0.155652  0.067552  0.074468
# childsharechange   -0.237124  0.000513  -0.150022 -0.042132 -0.044562
# O65realchange       0.205965 -0.181417   0.010693  0.960333  0.956278
# taxbaserealchange   0.134670 -0.193012   0.003910  0.524420  0.559380
# childrealchange    -0.000457 -0.069045  -0.001271 -0.281629 -0.248374
# totalrealchange     0.165426 -0.204061   0.006544  0.648356  0.674174
# homerealchange      0.045569 -0.025913   0.707016  0.006303  0.006166
#
#                     O*taxbase     O*O65  O*Pchild  O*Ptaxbase    O*PO65  \
# total                0.998458  0.979518  0.055831    0.193965 -0.213302
# child                0.989475  0.960071  0.089734    0.182301 -0.229683
# taxbase              0.999227  0.976121  0.051871    0.201042 -0.216380
# O65                  0.981210  0.998924  0.016670    0.175352 -0.166351
# Pchild               0.029060 -0.006601  0.904627   -0.279310 -0.465878
# Ptaxbase             0.223325  0.190846 -0.124669    0.908590 -0.695690
# PO65                -0.210842 -0.156462 -0.577254   -0.558706  0.940877
# homevalue            0.009820  0.010996  0.129285   -0.108061 -0.007354
# O*total              0.999465  0.981887  0.052683    0.193224 -0.210204
# O*child              0.992711  0.965077  0.085750    0.179948 -0.224526
# O*taxbase            1.000000  0.978891  0.047635    0.201239 -0.213246
# O*O65                0.978891  1.000000  0.012805    0.171251 -0.159760
# O*Pchild             0.047635  0.012805  1.000000   -0.276064 -0.543510
# O*Ptaxbase           0.201239  0.171251 -0.276064    1.000000 -0.656665
# O*PO65              -0.213246 -0.159760 -0.543510   -0.656665  1.000000
# O*homevalue          0.007699  0.008563  0.110773   -0.041947 -0.050685
# O65percchange        0.121660  0.111064  0.032067    0.437408 -0.406994
# taxbasepercchange    0.195078  0.189421  0.293359    0.105914 -0.322462
# childpercchange      0.061151  0.054965 -0.041439    0.089787 -0.045768
# totalpercchange      0.186066  0.185772  0.161362    0.169108 -0.274028
# homepercchange       0.005506  0.006308  0.072088   -0.111292  0.040630
# O65sharechange      -0.029695 -0.017829 -0.193389    0.175878 -0.001998
# taxbasesharechange   0.066328  0.058338  0.339295   -0.146790 -0.138181
# childsharechange    -0.040575 -0.044227 -0.170825   -0.021214  0.152480
# O65realchange        0.957022  0.955823  0.036824    0.190846 -0.195574
# taxbaserealchange    0.519624  0.464899  0.117634    0.103672 -0.182503
# childrealchange     -0.286098 -0.314541  0.058733    0.005672 -0.050551
# totalrealchange      0.643172  0.604905  0.096442    0.142619 -0.199926
# homerealchange       0.006187  0.006985  0.072044   -0.110861  0.040288
#
#                     O*homevalue  O65percchange  taxbasepercchange  \
# total                  0.007789       0.128440           0.209619
# child                  0.007581       0.131934           0.219071
# taxbase                0.007640       0.127243           0.206593
# O65                    0.008585       0.124498           0.201911
# Pchild                 0.103931      -0.071997           0.212440
# Ptaxbase              -0.100934       0.246329           0.312355
# PO65                   0.007042      -0.154344          -0.425072
# homevalue              0.707055      -0.245789           0.057291
# O*total                0.007800       0.121789           0.197687
# O*child                0.007554       0.125688           0.205761
# O*taxbase              0.007699       0.121660           0.195078
# O*O65                  0.008563       0.111064           0.189421
# O*Pchild               0.110773       0.032067           0.293359
# O*Ptaxbase            -0.041947       0.437408           0.105914
# O*PO65                -0.050685      -0.406994          -0.322462
# O*homevalue            1.000000       0.091504          -0.022325
# O65percchange          0.091504       1.000000           0.234413
# taxbasepercchange     -0.022325       0.234413           1.000000
# childpercchange       -0.004199       0.159152           0.313131
# totalpercchange        0.035866       0.472360           0.889051
# homepercchange        -0.000221      -0.439631           0.102747
# O65sharechange         0.161666       0.675608          -0.358545
# taxbasesharechange    -0.142615      -0.422032           0.496273
# childsharechange      -0.010316      -0.238982          -0.172501
# O65realchange          0.008383       0.192070           0.261520
# taxbaserealchange      0.002851       0.186627           0.354927
# childrealchange       -0.001168       0.094059           0.214347
# totalrealchange        0.004968       0.210714           0.364192
# homerealchange        -0.000201      -0.439082           0.103342
#
#                     childpercchange  totalpercchange  homepercchange  \
# total                      0.068192         0.201915        0.005624
# child                      0.074279         0.209414        0.005552
# taxbase                    0.067261         0.198189        0.005467
# O65                        0.060501         0.200816        0.006291
# Pchild                     0.305602         0.187348       -0.016732
# Ptaxbase                  -0.080501         0.185745        0.045172
# PO65                      -0.162684        -0.298928       -0.025633
# homevalue                 -0.268372         0.001871        0.707001
# O*total                    0.061399         0.188699        0.005630
# O*child                    0.064380         0.194251        0.005524
# O*taxbase                  0.061151         0.186066        0.005506
# O*O65                      0.054965         0.185772        0.006308
# O*Pchild                  -0.041439         0.161362        0.072088
# O*Ptaxbase                 0.089787         0.169108       -0.111292
# O*PO65                    -0.045768        -0.274028        0.040630
# O*homevalue               -0.004199         0.035866       -0.000221
# O65percchange              0.159152         0.472360       -0.439631
# taxbasepercchange          0.313131         0.889051        0.102747
# childpercchange            1.000000         0.557328       -0.375600
# totalpercchange            0.557328         1.000000       -0.033925
# homepercchange            -0.375600        -0.033925        1.000000
# O65sharechange            -0.353038        -0.120787       -0.188600
# taxbasesharechange        -0.397019         0.051186        0.362782
# childsharechange           0.800232         0.068086       -0.201756
# O65realchange              0.088002         0.274193        0.005967
# taxbaserealchange          0.165618         0.363313        0.002108
# childrealchange            0.179330         0.253220       -0.000684
# totalrealchange            0.173419         0.383316        0.003615
# homerealchange            -0.375308        -0.033222        0.999999
#
#                     O65sharechange  taxbasesharechange  childsharechange  \
# total                    -0.030893            0.068532         -0.041844
# child                    -0.038126            0.074600         -0.041041
# taxbase                  -0.031839            0.068400         -0.040692
# O65                      -0.013852            0.057225         -0.047214
# Pchild                   -0.371907            0.110191          0.265407
# Ptaxbase                 -0.066038            0.279792         -0.237124
# PO65                      0.336869           -0.320025          0.000513
# homevalue                -0.018953            0.155652         -0.150022
# O*total                  -0.029504            0.067552         -0.042132
# O*child                  -0.034496            0.074468         -0.044562
# O*taxbase                -0.029695            0.066328         -0.040575
# O*O65                    -0.017829            0.058338         -0.044227
# O*Pchild                 -0.193389            0.339295         -0.170825
# O*Ptaxbase                0.175878           -0.146790         -0.021214
# O*PO65                   -0.001998           -0.138181          0.152480
# O*homevalue               0.161666           -0.142615         -0.010316
# O65percchange             0.675608           -0.422032         -0.238982
# taxbasepercchange        -0.358545            0.496273         -0.172501
# childpercchange          -0.353038           -0.397019          0.800232
# totalpercchange          -0.120787            0.051186          0.068086
# homepercchange           -0.188600            0.362782         -0.201756
# O65sharechange            1.000000           -0.560650         -0.422303
# taxbasesharechange       -0.560650            1.000000         -0.512795
# childsharechange         -0.422303           -0.512795          1.000000
# O65realchange             0.008050            0.049105         -0.061508
# taxbaserealchange        -0.062512            0.080632         -0.024301
# childrealchange          -0.063315           -0.014119          0.078901
# totalrealchange          -0.046701            0.063950         -0.022316
# homerealchange           -0.188477            0.362732         -0.201831
#
#                     O65realchange  taxbaserealchange  childrealchange  \
# total                    0.967329           0.556484        -0.247237
# child                    0.961038           0.593420        -0.200133
# taxbase                  0.963292           0.552807        -0.254158
# O65                      0.968425           0.496786        -0.285924
# Pchild                   0.009427           0.104596         0.091601
# Ptaxbase                 0.205965           0.134670        -0.000457
# PO65                    -0.181417          -0.193012        -0.069045
# homevalue                0.010693           0.003910        -0.001271
# O*total                  0.960333           0.524420        -0.281629
# O*child                  0.956278           0.559380        -0.248374
# O*taxbase                0.957022           0.519624        -0.286098
# O*O65                    0.955823           0.464899        -0.314541
# O*Pchild                 0.036824           0.117634         0.058733
# O*Ptaxbase               0.190846           0.103672         0.005672
# O*PO65                  -0.195574          -0.182503        -0.050551
# O*homevalue              0.008383           0.002851        -0.001168
# O65percchange            0.192070           0.186627         0.094059
# taxbasepercchange        0.261520           0.354927         0.214347
# childpercchange          0.088002           0.165618         0.179330
# totalpercchange          0.274193           0.363313         0.253220
# homepercchange           0.005967           0.002108        -0.000684
# O65sharechange           0.008050          -0.062512        -0.063315
# taxbasesharechange       0.049105           0.080632        -0.014119
# childsharechange        -0.061508          -0.024301         0.078901
# O65realchange            1.000000           0.649658        -0.121398
# taxbaserealchange        0.649658           1.000000         0.540774
# childrealchange         -0.121398           0.540774         1.000000
# totalrealchange          0.773554           0.974169         0.485065
# homerealchange           0.006738           0.002678        -0.000628
#
#                     totalrealchange  homerealchange
# total                      0.677535        0.006309
# child                      0.706683        0.006204
# taxbase                    0.672116        0.006158
# O65                        0.635076        0.006987
# Pchild                     0.084717       -0.016808
# Ptaxbase                   0.165426        0.045569
# PO65                      -0.204061       -0.025913
# homevalue                  0.006544        0.707016
# O*total                    0.648356        0.006303
# O*child                    0.674174        0.006166
# O*taxbase                  0.643172        0.006187
# O*O65                      0.604905        0.006985
# O*Pchild                   0.096442        0.072044
# O*Ptaxbase                 0.142619       -0.110861
# O*PO65                    -0.199926        0.040288
# O*homevalue                0.004968       -0.000201
# O65percchange              0.210714       -0.439082
# taxbasepercchange          0.364192        0.103342
# childpercchange            0.173419       -0.375308
# totalpercchange            0.383316       -0.033222
# homepercchange             0.003615        0.999999
# O65sharechange            -0.046701       -0.188477
# taxbasesharechange         0.063950        0.362732
# childsharechange          -0.022316       -0.201831
# O65realchange              0.773554        0.006738
# taxbaserealchange          0.974169        0.002678
# childrealchange            0.485065       -0.000628
# totalrealchange            1.000000        0.004285
# homerealchange             0.004285        1.000000

# %% [markdown]
# ### Export
#
# I'm going to export here and we can explore the data further in a new notebook - I want to separate prep for simplicity's sake.

# %%
data.to_csv('../output/csv/agegroupshomevalue_2014_2019_county.csv', index = False)
