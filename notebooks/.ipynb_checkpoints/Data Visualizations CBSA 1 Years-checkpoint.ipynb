# %% [markdown]
# # This notebook goes through the process of conducting a multiple linear regression to get information about aging populations in US CBSAs.

# %% [markdown]
# ###### Imports

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.font_manager
from sklearn.linear_model import LinearRegression

# %% [markdown]
# First I want to think through what I need to predict. In this case, let's think through what becomes relevant when we're thinking about services for and policies related to the elderly...
#
# Maybe we want to predict population density of the elderly because this will have some bearing on the types of transportation services an area needs to be prepared to provide. Maybe we want to predict total share of population because if that share grows there may be a greater burden on the tax base - those who are still working, and that's something that a government needs to be prepared for.

# %% [markdown]
# First let's bring in the data

# %%
data = pd.read_csv('../output/csv/decadeCBSAs.csv')
data.head()
# Out:
#                        NAME                                 CBSA  \
# 0  Athens-Clarke County, GA  Athens-Clarke County, GA Metro Area
# 1  Athens-Clarke County, GA  Athens-Clarke County, GA Metro Area
# 2  Athens-Clarke County, GA  Athens-Clarke County, GA Metro Area
# 3  Athens-Clarke County, GA  Athens-Clarke County, GA Metro Area
# 4  Athens-Clarke County, GA  Athens-Clarke County, GA Metro Area
#
#             GEOID  year           geoyearID   total  child  taxbase    O65  \
# 0  310M100US12020  2010  310M100US120202010  192738  40837   132080  19821
# 1  310M100US12020  2011  310M100US120202011  193317  39216   133321  20780
# 2  310M100US12020  2012  310M100US120202012  194337  39979   131774  22584
# 3  310M200US12020  2013  310M200US120202013  197357  39358   135387  22612
# 4  310M200US12020  2014  310M200US120202014  197268  39567   134509  23192
#
#    Pchild  Ptaxbase  PO65  homevalue State MetroMicro  CBSAFIPS  popdensity  \
# ...

# %% [markdown]
# Let's create some scatterplots looking at relationships between these variables, year agnostic.

# %%
plt.rcParams['figure.constrained_layout.use'] = True

# %%
fig, axs = plt.subplots(4, 3, figsize=(20,10))
axs[0,0].scatter(data['total'], data['child'], color='saddlebrown', marker = '2')
axs[0, 0].set_title("Total and Child Pop", fontsize = 9, font = 'helvetica')
axs[0,1].scatter(data['total'], data['taxbase'], color='saddlebrown', marker = '2')
axs[0, 1].set_title("Total and Working Pop", fontsize = 9, font = 'helvetica')
axs[0,2].scatter(data['total'], data['O65'], color='saddlebrown', marker = '2')
axs[0, 2].set_title("Total and Elderly Pop", fontsize = 9, font = 'helvetica')
axs[1,0].scatter(data['total'], data['Pchild'], color='saddlebrown', marker = '2')
axs[1, 0].set_title("Total and Child %", fontsize = 9, font = 'helvetica')
axs[1,1].scatter(data['total'], data['Ptaxbase'], color='saddlebrown', marker = '2')
axs[1, 1].set_title("Total and Working %", fontsize = 9, font = 'helvetica')
axs[1,2].scatter(data['total'], data['PO65'], color='saddlebrown', marker = '2')
axs[1, 2].set_title("Total and Elderly %", fontsize = 9, font = 'helvetica')
axs[2,0].scatter(data['total'], data['popdensity'], color='saddlebrown', marker = '2')
axs[2, 0].set_title("Total and Population Density", fontsize = 9, font = 'helvetica')
axs[2,1].scatter(data['total'], data['childpopdensity'], color='saddlebrown', marker = '2')
axs[2, 1].set_title("Total and Child Population Density", fontsize = 9, font = 'helvetica')
axs[2,2].scatter(data['total'], data['tbpopdensity'], color='saddlebrown', marker = '2')
axs[2, 2].set_title("Total and Working Population Density", fontsize = 9, font = 'helvetica')
axs[3,0].scatter(data['total'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 0].set_title("Total and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,1].scatter(data['tbpopdensity'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 1].set_title("Working and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,2].scatter(data['childpopdensity'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 2].set_title("Child and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,2].scatter(data['childpopdensity'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 2].set_title("Child and Elderly Population Density", fontsize = 9, font = 'helvetica')
# fig.constrained_layout()
# Out:
# Text(0.5, 1.0, 'Child and Elderly Population Density')

# %% [markdown]
# I'm seeing that the strongest linear relationships are the ones at the top... no surprise, and unfortunately the least strong appears to be total population and elderly population, however it's still very strong just not a direct line like child and taxbase populations.. I'm going to see what other things look like with elderly population.

# %%
fig, axs = plt.subplots(4, 3, figsize=(20,10))
axs[0,0].scatter(data['O65'], data['child'], color='saddlebrown', marker = '2')
axs[0, 0].set_title("Elderly and Child Pop", fontsize = 9, font = 'helvetica')
axs[0,1].scatter(data['O65'], data['taxbase'], color='saddlebrown', marker = '2')
axs[0, 1].set_title("Elderly and Working Pop", fontsize = 9, font = 'helvetica')
axs[0,2].scatter(data['O65'], data['O65'], color='saddlebrown', marker = '2')
axs[0, 2].set_title("Elderly and Elderly Pop", fontsize = 9, font = 'helvetica')
axs[1,0].scatter(data['O65'], data['Pchild'], color='saddlebrown', marker = '2')
axs[1, 0].set_title("Elderly and Child %", fontsize = 9, font = 'helvetica')
axs[1,1].scatter(data['O65'], data['Ptaxbase'], color='saddlebrown', marker = '2')
axs[1, 1].set_title("Elderly and Working %", fontsize = 9, font = 'helvetica')
axs[1,2].scatter(data['O65'], data['PO65'], color='saddlebrown', marker = '2')
axs[1, 2].set_title("Elderly and Elderly %", fontsize = 9, font = 'helvetica')
axs[2,0].scatter(data['O65'], data['popdensity'], color='saddlebrown', marker = '2')
axs[2, 0].set_title("Elderly and Population Density", fontsize = 9, font = 'helvetica')
axs[2,1].scatter(data['O65'], data['childpopdensity'], color='saddlebrown', marker = '2')
axs[2, 1].set_title("Elderly and Child Population Density", fontsize = 9, font = 'helvetica')
axs[2,2].scatter(data['O65'], data['tbpopdensity'], color='saddlebrown', marker = '2')
axs[2, 2].set_title("Elderly and Working Population Density", fontsize = 9, font = 'helvetica')
axs[3,0].scatter(data['O65'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 0].set_title("Elderly and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,1].scatter(data['O65'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 1].set_title("Elderly and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,2].scatter(data['O65'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 2].set_title("Elderly and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,2].scatter(data['O65'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 2].set_title("Elderly and Elderly Population Density", fontsize = 9, font = 'helvetica')
# fig.constrained_layout()
# Out:
# Text(0.5, 1.0, 'Elderly and Elderly Population Density')

# %% [markdown]
# I think the question is... do we want to assume some level of growth with something (i.e. population) and see our peers off of that - 5, 10 years..., or do we want to impose another set of conditions for near term effects and find peers that way? Both? ahh.

# %% [markdown]
# I'm going to try some stuff with year.

# %%
plt.scatter(data['homevalue'], data['total'], color='saddlebrown', marker = '2')
plt.title('Home Value and Total Population')
# Out:
# Text(0.5, 1.0, 'Home Value and Total Population')

# %%
plt.scatter(data['homevalue'], data['O65'], color='saddlebrown', marker = '2')
plt.title('Home Value and Total Population')
# Out:
# Text(0.5, 1.0, 'Home Value and Total Population')

# %%
fig, axs = plt.subplots(4, 3, figsize=(20,10))
axs[0,0].scatter(data['homevalue'], data['child'], color='saddlebrown', marker = '2')
axs[0, 0].set_title("Home Value and Child Pop", fontsize = 9, font = 'helvetica')
axs[0,1].scatter(data['homevalue'], data['taxbase'], color='saddlebrown', marker = '2')
axs[0, 1].set_title("Home Value and Working Pop", fontsize = 9, font = 'helvetica')
axs[0,2].scatter(data['homevalue'], data['O65'], color='saddlebrown', marker = '2')
axs[0, 2].set_title("Home Value and Elderly Pop", fontsize = 9, font = 'helvetica')
axs[1,0].scatter(data['homevalue'], data['Pchild'], color='saddlebrown', marker = '2')
axs[1, 0].set_title("Home Value and Child %", fontsize = 9, font = 'helvetica')
axs[1,1].scatter(data['homevalue'], data['Ptaxbase'], color='saddlebrown', marker = '2')
axs[1, 1].set_title("Home Value and Working %", fontsize = 9, font = 'helvetica')
axs[1,2].scatter(data['homevalue'], data['PO65'], color='saddlebrown', marker = '2')
axs[1, 2].set_title("Home Value and Elderly %", fontsize = 9, font = 'helvetica')
axs[2,0].scatter(data['homevalue'], data['popdensity'], color='saddlebrown', marker = '2')
axs[2, 0].set_title("Home Value and Population Density", fontsize = 9, font = 'helvetica')
axs[2,1].scatter(data['homevalue'], data['childpopdensity'], color='saddlebrown', marker = '2')
axs[2, 1].set_title("Home Value and Child Population Density", fontsize = 9, font = 'helvetica')
axs[2,2].scatter(data['homevalue'], data['tbpopdensity'], color='saddlebrown', marker = '2')
axs[2, 2].set_title("Home Value and Working Population Density", fontsize = 9, font = 'helvetica')
axs[3,0].scatter(data['homevalue'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 0].set_title("Home Value and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,1].scatter(data['homevalue'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 1].set_title("Home Value and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,2].scatter(data['homevalue'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 2].set_title("Home Value and Elderly Population Density", fontsize = 9, font = 'helvetica')
axs[3,2].scatter(data['homevalue'], data['O65popdensity'], color='saddlebrown', marker = '2')
axs[3, 2].set_title("Home Value and Elderly Population Density", fontsize = 9, font = 'helvetica')
# fig.constrained_layout()
# Out:
# Text(0.5, 1.0, 'Home Value and Elderly Population Density')
